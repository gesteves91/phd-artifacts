# %% [markdown]
# #### Import the libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pycaret.classification import *

# %%
df = pd.read_csv('../data/final/defects_smells.csv', index_col=0)
df_type = df['Type']
df.shape
# Out:
# (19085, 85)

# %% [markdown]
# #### Remove duplicates

# %%
duplicate_rows = df[df.duplicated()]
len(duplicate_rows)
# Out:
# 61

# %% [markdown]
# ##### Drop the method-level code smells and the different targets that are not necessary for the model. For instance, this code is set up to the Refused Bequest model. To train other models, comment the Refused Bequest line, and remove the target that you want to model.

# %%
df = df.drop('LongName', 1)
df = df.drop('Name', 1)
df = df.drop('Parent', 1)
df = df.drop('Component', 1)
df = df.drop('Path', 1)
df = df.drop('Line', 1)
df = df.drop('EndLine', 1)
df = df.drop('Column', 1)
df = df.drop('EndColumn', 1)
df = df.drop('Type', 1)

df = df.drop('fe', 1)
df = df.drop('dico', 1)
df = df.drop('ic', 1)
df = df.drop('lpl', 1)
df = df.drop('mc', 1)
df = df.drop('ss', 1)
df = df.drop('lm', 1)

#df = df.drop('rb', 1)
df = df.drop('cdsbp', 1)
df = df.drop('dacl', 1)
df = df.drop('lc', 1)
df = df.drop('sc', 1)
df = df.drop('sg', 1)
df = df.drop('gc', 1)

df = df.drop('bug', 1)

# %% [markdown]
# #### Check the correlation and remove the high-correlated features from the dataset

# %%
corr = df.corr()
threshold = 0.99

columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= threshold:
            print(df.columns[i],df.columns[j])
            if columns[j]:
                columns[j] = False
selected_columns = df.columns[columns]
high_corr = set(df.columns) - set(selected_columns)
df = df[selected_columns]
# Out:
# LDC LLDC
# CLOC TCLOC
# NA TNA
# NLPA TNLPA
# NPA TNPA

# %%
df['Type'] = df_type

# %% [markdown]
# ##### Put the target on the end of the dataframe. Here, as an example, our target is the presence of the Refused Bequest.

# %%
results = df.rb.values
df = df.drop('rb', axis=1)
df['rb'] = results

# %% [markdown]
# #### Setup the model creation with pycaret

# %%
s = setup(data=df, target='rb', feature_selection=True,
          remove_multicollinearity=True,
          multicollinearity_threshold=0.85,
          feature_selection_method='boruta',
          fix_imbalance=True, fold=10)
# Out:
# <style type="text/css">
# #T_74cd3_row42_col1, #T_74cd3_row44_col1, #T_74cd3_row52_col1, #T_74cd3_row58_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_74cd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74cd3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_74cd3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74cd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74cd3_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_74cd3_row0_col1" class="data row0 col1" >3426</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_74cd3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_74cd3_row1_col1" class="data row1 col1" >rb</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_74cd3_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_74cd3_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_74cd3_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_74cd3_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_74cd3_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_74cd3_row4_col1" class="data row4 col1" >(19085, 57)</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_74cd3_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_74cd3_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_74cd3_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_74cd3_row6_col1" class="data row6 col1" >51</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_74cd3_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_74cd3_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_74cd3_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_74cd3_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_74cd3_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_74cd3_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_74cd3_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_74cd3_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_74cd3_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_74cd3_row11_col1" class="data row11 col1" >(13359, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_74cd3_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_74cd3_row12_col1" class="data row12 col1" >(5726, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_74cd3_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_74cd3_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_74cd3_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_74cd3_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_74cd3_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_74cd3_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_74cd3_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_74cd3_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_74cd3_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_74cd3_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_74cd3_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_74cd3_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_74cd3_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_74cd3_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_74cd3_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_74cd3_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_74cd3_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_74cd3_row21_col1" class="data row21 col1" >3b66</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_74cd3_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_74cd3_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_74cd3_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_74cd3_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_74cd3_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_74cd3_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_74cd3_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_74cd3_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_74cd3_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_74cd3_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_74cd3_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_74cd3_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_74cd3_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_74cd3_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_74cd3_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_74cd3_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74cd3_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_74cd3_row30_col0" class="data row30 col0" >

# %%
df = get_config('X')

# %% [markdown]
# #### Plot the features

# %%
selected_features = list(get_config('X').columns)
with open('../../results/features.csv', 'w') as f:
     f.write("\n".join(selected_features))

# %% [markdown]
# ##### Train the models. In this code the model was trained for the Refused Bequest smell. From all models, we selected the top-5 in terms of F1.

# %%
top5_models = compare_models(n_select=5, sort='f1')
# Out:
# <style type="text/css">
# #T_2c31d th {
#   text-align: left;
# }
# #T_2c31d_row0_col0, #T_2c31d_row0_col3, #T_2c31d_row0_col4, #T_2c31d_row1_col0, #T_2c31d_row1_col1, #T_2c31d_row1_col2, #T_2c31d_row1_col3, #T_2c31d_row1_col5, #T_2c31d_row1_col6, #T_2c31d_row1_col7, #T_2c31d_row2_col0, #T_2c31d_row2_col1, #T_2c31d_row2_col2, #T_2c31d_row2_col3, #T_2c31d_row2_col4, #T_2c31d_row2_col5, #T_2c31d_row2_col6, #T_2c31d_row2_col7, #T_2c31d_row3_col0, #T_2c31d_row3_col1, #T_2c31d_row3_col2, #T_2c31d_row3_col3, #T_2c31d_row3_col4, #T_2c31d_row3_col5, #T_2c31d_row3_col6, #T_2c31d_row3_col7, #T_2c31d_row4_col0, #T_2c31d_row4_col1, #T_2c31d_row4_col2, #T_2c31d_row4_col3, #T_2c31d_row4_col4, #T_2c31d_row4_col5, #T_2c31d_row4_col6, #T_2c31d_row4_col7, #T_2c31d_row5_col0, #T_2c31d_row5_col1, #T_2c31d_row5_col2, #T_2c31d_row5_col3, #T_2c31d_row5_col4, #T_2c31d_row5_col5, #T_2c31d_row5_col6, #T_2c31d_row5_col7, #T_2c31d_row6_col0, #T_2c31d_row6_col1, #T_2c31d_row6_col2, #T_2c31d_row6_col3, #T_2c31d_row6_col4, #T_2c31d_row6_col5, #T_2c31d_row6_col6, #T_2c31d_row6_col7, #T_2c31d_row7_col0, #T_2c31d_row7_col1, #T_2c31d_row7_col2, #T_2c31d_row7_col3, #T_2c31d_row7_col4, #T_2c31d_row7_col5, #T_2c31d_row7_col6, #T_2c31d_row7_col7, #T_2c31d_row8_col0, #T_2c31d_row8_col1, #T_2c31d_row8_col2, #T_2c31d_row8_col3, #T_2c31d_row8_col4, #T_2c31d_row8_col5, #T_2c31d_row8_col6, #T_2c31d_row8_col7, #T_2c31d_row9_col0, #T_2c31d_row9_col1, #T_2c31d_row9_col2, #T_2c31d_row9_col3, #T_2c31d_row9_col4, #T_2c31d_row9_col5, #T_2c31d_row9_col6, #T_2c31d_row9_col7, #T_2c31d_row10_col0, #T_2c31d_row10_col1, #T_2c31d_row10_col2, #T_2c31d_row10_col3, #T_2c31d_row10_col4, #T_2c31d_row10_col5, #T_2c31d_row10_col6, #T_2c31d_row10_col7, #T_2c31d_row11_col0, #T_2c31d_row11_col1, #T_2c31d_row11_col2, #T_2c31d_row11_col4, #T_2c31d_row11_col5, #T_2c31d_row11_col6, #T_2c31d_row11_col7, #T_2c31d_row12_col0, #T_2c31d_row12_col1, #T_2c31d_row12_col2, #T_2c31d_row12_col3, #T_2c31d_row12_col4, #T_2c31d_row12_col5, #T_2c31d_row12_col6, #T_2c31d_row12_col7, #T_2c31d_row13_col0, #T_2c31d_row13_col1, #T_2c31d_row13_col2, #T_2c31d_row13_col3, #T_2c31d_row13_col4, #T_2c31d_row13_col5, #T_2c31d_row13_col6, #T_2c31d_row13_col7 {
#   text-align: left;
# }
# #T_2c31d_row0_col1, #T_2c31d_row0_col2, #T_2c31d_row0_col5, #T_2c31d_row0_col6, #T_2c31d_row0_col7, #T_2c31d_row1_col4, #T_2c31d_row11_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_2c31d_row0_col8, #T_2c31d_row1_col8, #T_2c31d_row2_col8, #T_2c31d_row3_col8, #T_2c31d_row4_col8, #T_2c31d_row5_col8, #T_2c31d_row6_col8, #T_2c31d_row7_col8, #T_2c31d_row8_col8, #T_2c31d_row9_col8, #T_2c31d_row10_col8, #T_2c31d_row11_col8, #T_2c31d_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_2c31d_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_2c31d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c31d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2c31d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_2c31d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_2c31d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_2c31d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_2c31d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_2c31d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_2c31d_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_2c31d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c31d_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_2c31d_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_2c31d_row0_col1" class="data row0 col1" >0.9725</td>
#       <td id="T_2c31d_row0_col2" class="data row0 col2" >0.9524</td>
#       <td id="T_2c31d_row0_col3" class="data row0 col3" >0.6348</td>
#       <td id="T_2c31d_row0_col4" class="data row0 col4" >0.9030</td>
#       <td id="T_2c31d_row0_col5" class="data row0 col5" >0.7441</td>
#       <td id="T_2c31d_row0_col6" class="data row0 col6" >0.7301</td>
#       <td id="T_2c31d_row0_col7" class="data row0 col7" >0.7435</td>
#       <td id="T_2c31d_row0_col8" class="data row0 col8" >1.1610</td>
#     </tr>
#     <tr>
#       <th id="T_2c31d_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_2c31d_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_2c31d_row1_col1" class="data row1 col1" >0.9718</td>
#       <td id="T_2c31d_row1_col2" class="data row1 col2" >0.9473</td>
#       <td id="T_2c31d_row1_col3" class="data row1 col3" >0.6219</td>
#       <td id="T_2c31d_row1_col4" class="data row1 col4" >0.9047</td>
#       <td id="T_2c31d_row1_col5" class="data row1 col5" >0.7357</td>
#       <td id="T_2c31d_row1_col6" class="data row1 col6" >0.7214</td>
#       <td id="T_2c31d_row1_col7" class="data row1 col7" >0.7363</td>
#       <td id="T_2c31d_row1_col8" class="data row1 col8" >1.4540</td>
#     </tr>
#     <tr>
#       <th id="T_2c31d_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_2c31d_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2c31d_row2_col1" class="data row2 col1" >0.9616</td>
#       <td id="T_2c31d_row2_col2" class="data row2 col2" >0.9153</td>
#       <td id="T_2c31d_row2_col3" class="data row2 col3" >0.5476</td>
#       <td id="T_2c31d_row2_col4" class="data row2 col4" >0.7827</td>
#       <td id="T_2c31d_row2_col5" class="data row2 col5" >0.6426</td>
#       <td id="T_2c31d_row2_col6" class="data row2 col6" >0.6231</td>
#       <td id="T_2c31d_row2_col7" class="data row2 col7" >0.6351</td>
#       <td id="T_2c31d_row2_col8" class="data row2 col8" >0.3750</td>
#     </tr>
#     <tr>
#       <th id="T_2c31d_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_2c31d_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#       <td id="T_2c31d_row3_col1" class="data row3 col1" >0.9433</td>
#       <td id="T_2c31d_row3_col2" class="data row3 col2" >0.7923</td>
#       <td id="T_2c31d_row3_col3" class="data row3 col3" >0.6195</td>
#       <td id="T_2c31d_row3_col4" class="data row3 col4" >0.5482</td>
#       <td id="T_2c31d_row3_col5" class="data row3 col5" >0.5808</td>
#       <td id="T_2c31d_row3_col6" class="data row3 col6" >0.5505</td>
#       <td id="T_2c31d_row3_col7" class="data row3 col7" >0.5522</td>
#       <td id="T_2c31d_row3_col8" class="data row3 col8" >0.1530</td>
#     </tr>
#     <tr>
#       <th id="T_2c31d_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_2c31d_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_2c31d_row4_col1" class="data row4 col1" >0.9287</td>
#       <td id="T_2c31d_row4_col2" class="data row4 col2" >0.8561</td>
#       <td id="T_2c31d_row4_col3" class="data row4 col3" >0.4876</td>
#       <td id="T_2c31d_row4_col4" class="data row4 col4" >0.4459</td>
#       <td id="T_2c31d_row4_col5" class="data row4 col5" >0.4651</td>
#       <td id="T_2c31d_row4_col6" class="data row4 col6" >0.4271</td>
#       <td id="T_2c31d_row4_col7" class="data row4 col7" >0.4279</td>
#       <td id="T_2c31d_row4_col8" class="data row4 col8" >3.4360</td>
#     </tr>
#     <tr>
#       <th id="T_2c31d_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_2c31d_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_2c31d_row5_col1" class="data row5 col1" >0.8430</td>
#       <td id="T_2c31d_row5_col2" class="data row5 col2" >0.8413</td>
#       <td id="T_2c31d_row5_col3" class="data row5 col3" >0.7373</td>
#       <td id="T_2c31d_row5_col4" class="data row5 col4" >0.2500</td>
#       <td id="T_2c31d_row5_col5" class="data row5 col5" >0.3731</td>
#       <td id="T_2c31d_row5_col6" class="data row5 col6" >0.3075</td>
#       <td id="T_2c31d_row5_col7" class="data row5 col7" >0.3671</td>

# %% [markdown]
# #### Tune the models

# %%
tuned_top5 = [
  tune_model(
    i,
    n_iter=30,
    optimize="f1",
    search_library='optuna',
    choose_better=True,
    early_stopping=True)
  for i in top5_models
  ]
# Out:
# <style type="text/css">
# #T_e8180_row10_col0, #T_e8180_row10_col1, #T_e8180_row10_col2, #T_e8180_row10_col3, #T_e8180_row10_col4, #T_e8180_row10_col5, #T_e8180_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e8180">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8180_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e8180_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e8180_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e8180_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e8180_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e8180_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e8180_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8180_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8180_row0_col0" class="data row0 col0" >0.9783</td>
#       <td id="T_e8180_row0_col1" class="data row0 col1" >0.9693</td>
#       <td id="T_e8180_row0_col2" class="data row0 col2" >0.7412</td>
#       <td id="T_e8180_row0_col3" class="data row0 col3" >0.9000</td>
#       <td id="T_e8180_row0_col4" class="data row0 col4" >0.8129</td>
#       <td id="T_e8180_row0_col5" class="data row0 col5" >0.8015</td>
#       <td id="T_e8180_row0_col6" class="data row0 col6" >0.8058</td>
#     </tr>
#     <tr>
#       <th id="T_e8180_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8180_row1_col0" class="data row1 col0" >0.9716</td>
#       <td id="T_e8180_row1_col1" class="data row1 col1" >0.9485</td>
#       <td id="T_e8180_row1_col2" class="data row1 col2" >0.6706</td>
#       <td id="T_e8180_row1_col3" class="data row1 col3" >0.8507</td>
#       <td id="T_e8180_row1_col4" class="data row1 col4" >0.7500</td>
#       <td id="T_e8180_row1_col5" class="data row1 col5" >0.7351</td>
#       <td id="T_e8180_row1_col6" class="data row1 col6" >0.7410</td>
#     </tr>
#     <tr>
#       <th id="T_e8180_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8180_row2_col0" class="data row2 col0" >0.9663</td>
#       <td id="T_e8180_row2_col1" class="data row2 col1" >0.9160</td>
#       <td id="T_e8180_row2_col2" class="data row2 col2" >0.5529</td>
#       <td id="T_e8180_row2_col3" class="data row2 col3" >0.8704</td>
#       <td id="T_e8180_row2_col4" class="data row2 col4" >0.6763</td>
#       <td id="T_e8180_row2_col5" class="data row2 col5" >0.6594</td>
#       <td id="T_e8180_row2_col6" class="data row2 col6" >0.6784</td>
#     </tr>
#     <tr>
#       <th id="T_e8180_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8180_row3_col0" class="data row3 col0" >0.9768</td>
#       <td id="T_e8180_row3_col1" class="data row3 col1" >0.9302</td>
#       <td id="T_e8180_row3_col2" class="data row3 col2" >0.6824</td>
#       <td id="T_e8180_row3_col3" class="data row3 col3" >0.9355</td>
#       <td id="T_e8180_row3_col4" class="data row3 col4" >0.7891</td>
#       <td id="T_e8180_row3_col5" class="data row3 col5" >0.7772</td>
#       <td id="T_e8180_row3_col6" class="data row3 col6" >0.7880</td>
#     </tr>
#     <tr>
#       <th id="T_e8180_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e8180_row4_col0" class="data row4 col0" >0.9708</td>
#       <td id="T_e8180_row4_col1" class="data row4 col1" >0.9158</td>
#       <td id="T_e8180_row4_col2" class="data row4 col2" >0.6118</td>
#       <td id="T_e8180_row4_col3" class="data row4 col3" >0.8966</td>
#       <td id="T_e8180_row4_col4" class="data row4 col4" >0.7273</td>
#       <td id="T_e8180_row4_col5" class="data row4 col5" >0.7124</td>
#       <td id="T_e8180_row4_col6" class="data row4 col6" >0.7270</td>
#     </tr>
#     <tr>
#       <th id="T_e8180_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e8180_row5_col0" class="data row5 col0" >0.9701</td>
#       <td id="T_e8180_row5_col1" class="data row5 col1" >0.9143</td>
#       <td id="T_e8180_row5_col2" class="data row5 col2" >0.5765</td>
#       <td id="T_e8180_row5_col3" class="data row5 col3" >0.9245</td>
#       <td id="T_e8180_row5_col4" class="data row5 col4" >0.7101</td>
#       <td id="T_e8180_row5_col5" class="data row5 col5" >0.6953</td>
#       <td id="T_e8180_row5_col6" class="data row5 col6" >0.7169</td>
#     </tr>
#     <tr>
#       <th id="T_e8180_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e8180_row6_col0" class="data row6 col0" >0.9760</td>
#       <td id="T_e8180_row6_col1" class="data row6 col1" >0.9315</td>
#       <td id="T_e8180_row6_col2" class="data row6 col2" >0.6824</td>
#       <td id="T_e8180_row6_col3" class="data row6 col3" >0.9206</td>
#       <td id="T_e8180_row6_col4" class="data row6 col4" >0.7838</td>
#       <td id="T_e8180_row6_col5" class="data row6 col5" >0.7714</td>
#       <td id="T_e8180_row6_col6" class="data row6 col6" >0.7811</td>
#     </tr>
#     <tr>
#       <th id="T_e8180_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e8180_row7_col0" class="data row7 col0" >0.9805</td>
#       <td id="T_e8180_row7_col1" class="data row7 col1" >0.9331</td>
#       <td id="T_e8180_row7_col2" class="data row7 col2" >0.7294</td>
#       <td id="T_e8180_row7_col3" class="data row7 col3" >0.9538</td>
#       <td id="T_e8180_row7_col4" class="data row7 col4" >0.8267</td>
#       <td id="T_e8180_row7_col5" class="data row7 col5" >0.8166</td>
#       <td id="T_e8180_row7_col6" class="data row7 col6" >0.8248</td>
#     </tr>
#     <tr>
#       <th id="T_e8180_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e8180_row8_col0" class="data row8 col0" >0.9716</td>
#       <td id="T_e8180_row8_col1" class="data row8 col1" >0.9290</td>
#       <td id="T_e8180_row8_col2" class="data row8 col2" >0.6118</td>
#       <td id="T_e8180_row8_col3" class="data row8 col3" >0.9123</td>
#       <td id="T_e8180_row8_col4" class="data row8 col4" >0.7324</td>
#       <td id="T_e8180_row8_col5" class="data row8 col5" >0.7180</td>
#       <td id="T_e8180_row8_col6" class="data row8 col6" >0.7340</td>
#     </tr>
#     <tr>
#       <th id="T_e8180_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e8180_row9_col0" class="data row9 col0" >0.9760</td>
#       <td id="T_e8180_row9_col1" class="data row9 col1" >0.9529</td>
#       <td id="T_e8180_row9_col2" class="data row9 col2" >0.6548</td>
#       <td id="T_e8180_row9_col3" class="data row9 col3" >0.9483</td>
#       <td id="T_e8180_row9_col4" class="data row9 col4" >0.7746</td>
#       <td id="T_e8180_row9_col5" class="data row9 col5" >0.7624</td>
#       <td id="T_e8180_row9_col6" class="data row9 col6" >0.7770</td>
#     </tr>
#     <tr>
#       <th id="T_e8180_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e8180_row10_col0" class="data row10 col0" >0.9738</td>
#       <td id="T_e8180_row10_col1" class="data row10 col1" >0.9340</td>
#       <td id="T_e8180_row10_col2" class="data row10 col2" >0.6514</td>
#       <td id="T_e8180_row10_col3" class="data row10 col3" >0.9113</td>
#       <td id="T_e8180_row10_col4" class="data row10 col4" >0.7583</td>
#       <td id="T_e8180_row10_col5" class="data row10 col5" >0.7449</td>
#       <td id="T_e8180_row10_col6" class="data row10 col6" >0.7574</td>
#     </tr>
#     <tr>
#       <th id="T_e8180_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e8180_row11_col0" class="data row11 col0" >0.0042</td>
#       <td id="T_e8180_row11_col1" class="data row11 col1" >0.0170</td>
#       <td id="T_e8180_row11_col2" class="data row11 col2" >0.0591</td>
#       <td id="T_e8180_row11_col3" class="data row11 col3" >0.0312</td>
#       <td id="T_e8180_row11_col4

# %% [markdown]
# #### Ensemble the top-5 models

# %%
blended_models = blend_models(
  tuned_top5,
  choose_better=True,
  optimize="f1")
# Out:
# <style type="text/css">
# #T_3699f_row10_col0, #T_3699f_row10_col1, #T_3699f_row10_col2, #T_3699f_row10_col3, #T_3699f_row10_col4, #T_3699f_row10_col5, #T_3699f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3699f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3699f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3699f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3699f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3699f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3699f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3699f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3699f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3699f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3699f_row0_col0" class="data row0 col0" >0.9783</td>
#       <td id="T_3699f_row0_col1" class="data row0 col1" >0.9642</td>
#       <td id="T_3699f_row0_col2" class="data row0 col2" >0.7294</td>
#       <td id="T_3699f_row0_col3" class="data row0 col3" >0.9118</td>
#       <td id="T_3699f_row0_col4" class="data row0 col4" >0.8105</td>
#       <td id="T_3699f_row0_col5" class="data row0 col5" >0.7991</td>
#       <td id="T_3699f_row0_col6" class="data row0 col6" >0.8047</td>
#     </tr>
#     <tr>
#       <th id="T_3699f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3699f_row1_col0" class="data row1 col0" >0.9746</td>
#       <td id="T_3699f_row1_col1" class="data row1 col1" >0.9511</td>
#       <td id="T_3699f_row1_col2" class="data row1 col2" >0.6824</td>
#       <td id="T_3699f_row1_col3" class="data row1 col3" >0.8923</td>
#       <td id="T_3699f_row1_col4" class="data row1 col4" >0.7733</td>
#       <td id="T_3699f_row1_col5" class="data row1 col5" >0.7601</td>
#       <td id="T_3699f_row1_col6" class="data row1 col6" >0.7678</td>
#     </tr>
#     <tr>
#       <th id="T_3699f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3699f_row2_col0" class="data row2 col0" >0.9656</td>
#       <td id="T_3699f_row2_col1" class="data row2 col1" >0.9396</td>
#       <td id="T_3699f_row2_col2" class="data row2 col2" >0.5529</td>
#       <td id="T_3699f_row2_col3" class="data row2 col3" >0.8545</td>
#       <td id="T_3699f_row2_col4" class="data row2 col4" >0.6714</td>
#       <td id="T_3699f_row2_col5" class="data row2 col5" >0.6541</td>
#       <td id="T_3699f_row2_col6" class="data row2 col6" >0.6714</td>
#     </tr>
#     <tr>
#       <th id="T_3699f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3699f_row3_col0" class="data row3 col0" >0.9790</td>
#       <td id="T_3699f_row3_col1" class="data row3 col1" >0.9556</td>
#       <td id="T_3699f_row3_col2" class="data row3 col2" >0.6824</td>
#       <td id="T_3699f_row3_col3" class="data row3 col3" >0.9831</td>
#       <td id="T_3699f_row3_col4" class="data row3 col4" >0.8056</td>
#       <td id="T_3699f_row3_col5" class="data row3 col5" >0.7949</td>
#       <td id="T_3699f_row3_col6" class="data row3 col6" >0.8097</td>
#     </tr>
#     <tr>
#       <th id="T_3699f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3699f_row4_col0" class="data row4 col0" >0.9708</td>
#       <td id="T_3699f_row4_col1" class="data row4 col1" >0.9465</td>
#       <td id="T_3699f_row4_col2" class="data row4 col2" >0.6000</td>
#       <td id="T_3699f_row4_col3" class="data row4 col3" >0.9107</td>
#       <td id="T_3699f_row4_col4" class="data row4 col4" >0.7234</td>
#       <td id="T_3699f_row4_col5" class="data row4 col5" >0.7087</td>
#       <td id="T_3699f_row4_col6" class="data row4 col6" >0.7259</td>
#     </tr>
#     <tr>
#       <th id="T_3699f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3699f_row5_col0" class="data row5 col0" >0.9701</td>
#       <td id="T_3699f_row5_col1" class="data row5 col1" >0.9378</td>
#       <td id="T_3699f_row5_col2" class="data row5 col2" >0.5647</td>
#       <td id="T_3699f_row5_col3" class="data row5 col3" >0.9412</td>
#       <td id="T_3699f_row5_col4" class="data row5 col4" >0.7059</td>
#       <td id="T_3699f_row5_col5" class="data row5 col5" >0.6911</td>
#       <td id="T_3699f_row5_col6" class="data row5 col6" >0.7163</td>
#     </tr>
#     <tr>
#       <th id="T_3699f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3699f_row6_col0" class="data row6 col0" >0.9768</td>
#       <td id="T_3699f_row6_col1" class="data row6 col1" >0.9603</td>
#       <td id="T_3699f_row6_col2" class="data row6 col2" >0.6824</td>
#       <td id="T_3699f_row6_col3" class="data row6 col3" >0.9355</td>
#       <td id="T_3699f_row6_col4" class="data row6 col4" >0.7891</td>
#       <td id="T_3699f_row6_col5" class="data row6 col5" >0.7772</td>
#       <td id="T_3699f_row6_col6" class="data row6 col6" >0.7880</td>
#     </tr>
#     <tr>
#       <th id="T_3699f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3699f_row7_col0" class="data row7 col0" >0.9783</td>
#       <td id="T_3699f_row7_col1" class="data row7 col1" >0.9593</td>
#       <td id="T_3699f_row7_col2" class="data row7 col2" >0.6706</td>
#       <td id="T_3699f_row7_col3" class="data row7 col3" >0.9828</td>
#       <td id="T_3699f_row7_col4" class="data row7 col4" >0.7972</td>
#       <td id="T_3699f_row7_col5" class="data row7 col5" >0.7862</td>
#       <td id="T_3699f_row7_col6" class="data row7 col6" >0.8022</td>
#     </tr>
#     <tr>
#       <th id="T_3699f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3699f_row8_col0" class="data row8 col0" >0.9686</td>
#       <td id="T_3699f_row8_col1" class="data row8 col1" >0.9551</td>
#       <td id="T_3699f_row8_col2" class="data row8 col2" >0.5647</td>
#       <td id="T_3699f_row8_col3" class="data row8 col3" >0.9057</td>
#       <td id="T_3699f_row8_col4" class="data row8 col4" >0.6957</td>
#       <td id="T_3699f_row8_col5" class="data row8 col5" >0.6800</td>
#       <td id="T_3699f_row8_col6" class="data row8 col6" >0.7012</td>
#     </tr>
#     <tr>
#       <th id="T_3699f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3699f_row9_col0" class="data row9 col0" >0.9730</td>
#       <td id="T_3699f_row9_col1" class="data row9 col1" >0.9642</td>
#       <td id="T_3699f_row9_col2" class="data row9 col2" >0.6071</td>
#       <td id="T_3699f_row9_col3" class="data row9 col3" >0.9444</td>
#       <td id="T_3699f_row9_col4" class="data row9 col4" >0.7391</td>
#       <td id="T_3699f_row9_col5" class="data row9 col5" >0.7256</td>
#       <td id="T_3699f_row9_col6" class="data row9 col6" >0.7454</td>
#     </tr>
#     <tr>
#       <th id="T_3699f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3699f_row10_col0" class="data row10 col0" >0.9735</td>
#       <td id="T_3699f_row10_col1" class="data row10 col1" >0.9534</td>
#       <td id="T_3699f_row10_col2" class="data row10 col2" >0.6337</td>
#       <td id="T_3699f_row10_col3" class="data row10 col3" >0.9262</td>
#       <td id="T_3699f_row10_col4" class="data row10 col4" >0.7511</td>
#       <td id="T_3699f_row10_col5" class="data row10 col5" >0.7377</td>
#       <td id="T_3699f_row10_col6" class="data row10 col6" >0.7533</td>
#     </tr>
#     <tr>
#       <th id="T_3699f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3699f_row11_col0" class="data row11 col0" >0.0044</td>
#       <td id="T_3699f_row11_col1" class="data row11 col1" >0.0090</td>
#       <td id="T_3699f_row11_col2" class="data row11 col2" >0.0596</td>
#       <td id="T_3699f_row11_col3" class="data row11 col3" >0.0377</td>
#       <td id="T_3699f_row11_col4

# %%
pred = predict_model(blended_models)
# Out:
# <style type="text/css">
# </style>
# <table id="T_367f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_367f7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_367f7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_367f7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_367f7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_367f7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_367f7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_367f7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_367f7_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_367f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_367f7_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_367f7_row0_col1" class="data row0 col1" >0.9742</td>
#       <td id="T_367f7_row0_col2" class="data row0 col2" >0.9524</td>
#       <td id="T_367f7_row0_col3" class="data row0 col3" >0.6313</td>
#       <td id="T_367f7_row0_col4" class="data row0 col4" >0.9030</td>
#       <td id="T_367f7_row0_col5" class="data row0 col5" >0.7431</td>
#       <td id="T_367f7_row0_col6" class="data row0 col6" >0.7299</td>
#       <td id="T_367f7_row0_col7" class="data row0 col7" >0.7429</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = pull()

# %% [markdown]
# #### Plot the ensemble model

# %%
result.to_csv('../../results/models.csv')

# %% [markdown]
# #### Finalize and save the ensemble model

# %%
final_best = finalize_model(blended_models)
save_model(final_best, '../../results/rb/model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='rb',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy=...
#                                              max_features=0.9779201704921807,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=3.746660669697568e-05,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=5,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=134,
#                                              n_iter_no_change=None,
#                                              presort='deprecated',
#                                              random_state=3426,
#                                              subsample=0.6397315018084915,
#                                              tol=0.0001, validation_fraction=0.1,
#                                              verbose=0, warm_start=False)]],
#           verbose=False),
#  '../../results/rb/model.pkl')

# %% [markdown]
# #### Interpret the ensemble model

# %%
interpret_model(tuned_top5[0], save=True)
